# %% [markdown]
# (A) Antoine's comment
# (C) Christian's comment
# (S) Stephanie's comment
#
# # INTRO.
# - A) there were ribosomes in spine head (?)
# - A) Emphasis in symmetrical/asymmetrical synapses
# - A) Francis Crick seminal paper on spines as locus for learning
#
# ## Morphology: how fixatives affect dimensions when you compare it with live conditions (A).
# - I thought about the asymmetry in diffusion for the spine neck. You said it was mostly due to volume, but how it depends on the diffusion coupling of the neck.
# - High resistance glutamate uncaging from Araya et al (Yuste), there was something odd in the interpretation.
# - A) Ruby-GABA is not clean, it may influence glu synapses.
#
# # TECHNIQUE STRATEGY
# - Does the procedure with DAB affect anything in the cell or tissue? (Apart from the landmarks)
# - What made labeling so hard?
# - C) explanation of 'plans' fig1c (I don't know what I meant here, nor what Christian said)
# - fig1c1 was not clear what it was for me.
# - fig1d: yellow color is hard to see.
#
# # DiS
# - fig 2a. That green line - Axon initial segment is problematic.
# - A) Are dendritic branches coming from a second cell an issue?
# - A) Electroporation two vs one dye?
# - A)How to have a proper way of describing this to avoid annoying reviewers?
# - A) Drawing of spine foot problematic
# - A/C) Color of the dendrite could be better is some other color  than brown is used
# - C) fig2d not clear pre and post synaptic compartments, neither PSDs. (Maybe drawing some region of interest?)
# - C) fig2d does not seem to provide new info from fig2c
# - fig2f how many other reconstructions are there of axons.
# -C) Are parameters for oblate/prolate somehow fine-tuned to produce that gap? Is the ratio L/D the best thing to plot? Does this provide any new info?
# - A) There is no bias/ no stat diff for DiS compared to SiS?
# - A) Fig3e How does 9% of DiS fit with data from others?
# - What are the error bars of 9%?
# - Does fig3f provide any new information? (not clear, not even clear why I wrote this either :) )
# - fig3 H and I switch places
#
# # SA
# - fig3 k : yellow is hard to see (but better than previous one)
# - A) fig 3 m2 change resistance to diffusion coupling or something else
# - where does SA due to size go?
# - A) Spine SA+ ----> spine + SA?
# - A) It will be difficult to write this thing of SA and size
# - S) Any way to normalize by size somehow?
# - C) Variability: is there a way to get the most "relevant" parameters?
#       - PCA -clustering algorithms -etc
#       - We could give a last go to this thing, if nothing, let's state it.
#
# # Fig 4 - Model
# - A) Leak resistance compare order of magnitude spine head to SA block thing.
# - A) We have to be more careful with intracellular Calcium
# -  You said something about Calcium which was not completely right - Ca current vs intracellular free Ca
# - A) axo-spinal to axo-spinus
#
# # Fig 5
# - C) Sketch - if 2 spines one with the shape of DiS and the other SiS.
# - A) profile of interneurons spiking: FS vs RS for SST+ int?
# - A) empty set symbol is diameter. Change it to something else
# - A) M Hausser stuff on localization synapses and electrotonic length
# - A) M Hausser debating with Kenneth (?)
# - A) "The subintegrative properties of dendrite" and lead back to F. Crick
# - Delta x is a bit confusing as it is right now.
# - Attenuation vs electrotonic length\
# - A) Goldfish work - electrotonic length, synapses getting bigger
#
# # Final comments
# C)
#  - The story should come together more nicely? Better glue needed
#  - Why do we had to work together?
#  - Is there a particular variable that has a big meaning?
#  - Can you identify things that are absent from the dataset?
#  - What are the parameters can be useful for others
#  - Include differences between DiS and SiS when presenting the model? What is characteristic of DiS? Not only inhibition, excitation too. Its size. Its effect in the soma. Anything.
