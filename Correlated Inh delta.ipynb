# %% [markdown]
# # Uncorrelated Inhibition
#
# Here we set the figures for the cases with only excitation in spines.

# %%
import numpy as np
from numpy.random import exponential, randint
from numpy import *   #ones, cumsum, sum, isscalar
from matplotlib.pylab import * 
# %matplotlib inline
plotose = True


import PS_lib as lb
import PS_storage as st

# %% [markdown]
# ## Setting up the model

# %% [markdown]
# ### Topology of the neuron
#
# We set first a simplistic neuron

# %%
# Parameter definitions
# Data is stored here      
data = st.dataStorage() # some default parameters defined.
data.dt = 0.1
data.NMDA = False

# Definition of the model.
lb.h.dt = data.dt
NMDA = data.NMDA
model = lb.loadNeuron("Basic2.hoc",axon=False)
# Adding piece of dendritic branch with spine
model.addDend(name="DendE",locus="dendA1",L=4.0,D=1.5)
model.addSpne(locus="DendE",ilocus=0.5,L=1.0,D=1.0,Lneck=1.0,Dneck=0.15)
data.model = model.__dict__
# Temperature of the neuron
lb.h.celsius = model.temperature
print("Topology:")
print(lb.h.topology())
# Out:
# 	0
# 	1
# 	1
# 	1
# 	1
# Topology:
#
# |-|       soma(0-1)
#    `|       dendA1c(0-1)
#      `|       dendA1(0-1)
#       `|       DendE(0-1)
#        `|       NSpne000(0-1)
#          `|       Spne000(0-1)
#    `|       dendB1(0-1)
#
# 1.0

# %% [markdown]
# ### Recording places
#
# We set recording vectors in all dendritic compartments, spine included

# %%
trec, vrec = lb.h.Vector(), lb.h.Vector()
gRec, iRec,  vspneRec = [], [], []
gNMDA_rec, iNMDA_rec = [], []
trec.record(lb.h._ref_t)
vrec.record(model.soma(0.5)._ref_v)


#n=0
vDendRec = []
caDendRec = []
#For all dendrites
for dend in model.dend:
    #Adding vectors for Voltage, and Calcium
    vDendRec.append(lb.h.Vector())
    caDendRec.append(lb.h.Vector())
    # Placing recording at mid-point in the dendritic branch
    vDendRec[-1].record(dend(0.5)._ref_v)
    # NO CALCIUM!?!?!
#Probably better to organize them in a dictionary        

# Spine voltage recording stuff
vspneRec.append(lb.h.Vector())
vspneRec.append(lb.h.Vector())
sp = model.spne[0]
vspneRec[0].record(sp(0.5)._ref_v)
sp = model.neck[0]
vspneRec[1].record(sp(0.5)._ref_v)
# Out:
# Vector[11]

# %% [markdown]
# ### Excitatory synapse
#
# We need to define the arrival time and dynamics. These parameters may be modified later

# %%
model.AMPAlist = []
model.ncAMPAlist = []

AMPA = lb.h.Exp2Syn(1,sec = model.spne[0])
tau1  = 0.5
tau2 = 8.0
AMPA.tau1 = tau1
AMPA.tau2 = tau2

nampa = 50
gmax = 15*nampa/1e6
stimE=lb.h.NetStim();stimE.number = 1; 
NC = lb.h.NetCon(stimE,AMPA,0,0,gmax)

model.AMPAlist.append(AMPA)
model.ncAMPAlist.append(NC)
NC.delay = 10

# NMDA part
nnmda = 2
gmaxN = 50*nnmda/1e6
lb.add_NMDAsyns(model, locs=[[0,0.5]], gmax=gmaxN,tau2=20.0)  
NMDA = model.NMDAlist[0]
NCN = model.ncNMDAlist[0]
stimN=lb.h.NetStim();stimN.number = 1;
NCN = lb.h.NetCon(stimN,NMDA,0,0,gmaxN)
model.ncNMDAlist[0] = NCN

# %% [markdown]
# ### Inhibitory synapse

# %%
nGABA = 35
gmaxG = nGABA*30e-6
lb.add_GABAsyns(model, locs=[[0,1]], spne=True, gmax=gmaxG,tau1=1.5,tau2=20.0)  
GABA = model.GABAlist[0]
NCG = model.ncGABAlist[0]
stimG=lb.h.NetStim();stimG.number = 1;
NCG = lb.h.NetCon(stimG,GABA,0,0,gmaxG)
model.ncGABAlist[0] = NCG

# %%
neck = model.neck[0]
Rneck = neck.L*1e-6/(neck.diam*1e-6/2.0)**2/pi*neck.Ra/100
dend = model.dend[0]
Rdend = dend.L*1e-6/(dend.diam*1e-6/2.0)**2/pi*dend.Ra/100
dend = model.dend[1]
Rdend +=dend.L*1e-6/2.0/(dend.diam*1e-6/2.0)**2/pi*dend.Ra/100
dend = model.dend[-1]
Rdend +=dend.L*1e-6/2.0/(dend.diam*1e-6/2.0)**2/pi*dend.Ra/100

print("The resistance of neck and the dendritic impedance are %.2f and %2.f MΩ (resp.)" %(Rneck/1e6,Rdend/1e6))
# Out:
# The resistance of neck and the dendritic impedance are 141.47 and 146 MΩ (resp.)

# %% [markdown]
# ## Plots
#
# xkcd is to give it non serious appearance

# %%
xkcd()

# %%
dend.Ra = 250
neck.Ra = 250
model.E_PAS = -65
model.soma.e_pas = -65
for dendp in model.dend:
    dendp.e_pas = -65
for sp in model.spne:
    sp.e_pas = -65
    
#rinh = 5.0
    
#tsGABA = cumsum(-log(rand(10))/rinh)*1000

#print(tsGABA)

#selG = abs(tsGABA-ton).argmin()


ton = 50


tG = ton+10

t_stop = 200
nampas = arange(0,100)
mes = zeros((nampas.shape[0],5))
vavg = zeros((int(t_stop/lb.h.dt+1),7))
for i,nampa in enumerate(nampas):
    #lb.add_somaStim(model,p=0.5,onset=ton,dur=2, amp =0.0)
    NC.delay = ton-50
    NCN.delay = ton-50
    NC.weight[0] = nampa *15/1e6
    NCN.weight[0] = gmaxN
    NCG.delay = tG-50
    NCG.weight[0] = 20*30/1e6 

    # ~ print(NC.weight[0])
    lb.h.finitialize(model.E_PAS)
    # ~ print(NC.weight[0])
    
    lb.neuron.run(t_stop)
    
    #plot(trec,vspneRec[0])    
    
    current = abs((array(vDendRec[-2])-array(vDendRec[0]))/Rdend)
    
    vavg[:,0] += array(vspneRec[0]) 
    vavg[:,1] += array(vspneRec[0])**2
    vavg[:,2] += array(vDendRec[0]) 
    vavg[:,3] += array(vDendRec[0])**2
    vavg[:,4] += array(vrec) 
    vavg[:,5] += array(vrec)**2
    vavg[:,6] += 1
        
    mes[i,:] = [nampa,max(vspneRec[0]),max(vDendRec[1]),max(vrec),max(current)]

vavg[:,:5] = vavg[:,:5]/vavg[0,6]
vavg[:,1] = sqrt(vavg[:,1]-vavg[:,0]**2)#/sqrt(vavg[0,6])
vavg[:,3] = sqrt(vavg[:,3]-vavg[:,2]**2)#/sqrt(vavg[0,6])
vavg[:,5] = sqrt(vavg[:,5]-vavg[:,4]**2)#/sqrt(vavg[0,6])

fig = figure(figsize=(13,6))
ax = fig.add_subplot(121)
    
plot(mes[:,-1]/1e-12,mes[:,1]+65,label="Spine head")
plot(mes[:,-1]/1e-12,mes[:,2]+65,label="Dendritic shaft")
plot(mes[:,-1]/1e-12,mes[:,3]+65,label="Soma")

xlabel("I(pA)")
ylabel("$\Delta$ V (mV)")

ax = fig.add_subplot(122)
vavt = vavg[:,:2]*1.0
vavt[:,0] = vavg[:,0]-vavg[0,0] 
plot(trec,vavt[:,0]-vavt[0,0],label="Spine head")
fill_between(trec,vavt[:,0]+vavt[:,1],vavt[:,0]-vavt[:,1])
xlabel("t (ms)")
ylabel("V (mV)")
xlim(40,100)
savefig("FigEI_pos10.pdf")
# Out:
# /export/home1/users/bssn/serna/environments/neuron/lib/python3.6/site-packages/ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in sqrt
# /export/home1/users/bssn/serna/environments/neuron/lib/python3.6/site-packages/ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in sqrt

# %%
dend.Ra = 250
neck.Ra = 250
model.E_PAS = -65
model.soma.e_pas = -65
for dendp in model.dend:
    dendp.e_pas = -65
for sp in model.spne:
    sp.e_pas = -65
    
#rinh = 5.0
    
#tsGABA = cumsum(-log(rand(10))/rinh)*1000

#print(tsGABA)

#selG = abs(tsGABA-ton).argmin()


ton = 50


tG = ton-5

t_stop = 200
nampas = arange(0,100)
mes = zeros((nampas.shape[0],5))
vavg = zeros((int(t_stop/lb.h.dt+1),7))
for i,nampa in enumerate(nampas):
    #lb.add_somaStim(model,p=0.5,onset=ton,dur=2, amp =0.0)
    NC.delay = ton-50
    NCN.delay = ton-50
    NC.weight[0] = nampa *15/1e6
    NCN.weight[0] = gmaxN
    NCG.delay = tG-50
    NCG.weight[0] = 20*30/1e6 

    # ~ print(NC.weight[0])
    lb.h.finitialize(model.E_PAS)
    # ~ print(NC.weight[0])
    
    lb.neuron.run(t_stop)
    
    #plot(trec,vspneRec[0])    
    
    current = abs((array(vDendRec[-2])-array(vDendRec[0]))/Rdend)
    
    vavg[:,0] += array(vspneRec[0]) 
    vavg[:,1] += array(vspneRec[0])**2
    vavg[:,2] += array(vDendRec[0]) 
    vavg[:,3] += array(vDendRec[0])**2
    vavg[:,4] += array(vrec) 
    vavg[:,5] += array(vrec)**2
    vavg[:,6] += 1
        
    mes[i,:] = [nampa,max(vspneRec[0]),max(vDendRec[1]),max(vrec),max(current)]

vavg[:,:5] = vavg[:,:5]/vavg[0,6]
vavg[:,1] = sqrt(vavg[:,1]-vavg[:,0]**2)#/sqrt(vavg[0,6])
vavg[:,3] = sqrt(vavg[:,3]-vavg[:,2]**2)#/sqrt(vavg[0,6])
vavg[:,5] = sqrt(vavg[:,5]-vavg[:,4]**2)#/sqrt(vavg[0,6])

fig = figure(figsize=(13,6))
ax = fig.add_subplot(121)
    
plot(mes[:,-1]/1e-12,mes[:,1]+65,label="Spine head")
plot(mes[:,-1]/1e-12,mes[:,2]+65,label="Dendritic shaft")
plot(mes[:,-1]/1e-12,mes[:,3]+65,label="Soma")

xlabel("I(pA)")
ylabel("$\Delta$ V (mV)")

ax = fig.add_subplot(122)
vavt = vavg[:,:2]*1.0
vavt[:,0] = vavg[:,0]-vavg[0,0] 
plot(trec,vavt[:,0]-vavt[0,0],label="Spine head")
fill_between(trec,vavt[:,0]+vavt[:,1],vavt[:,0]-vavt[:,1])
xlabel("t (ms)")
ylabel("$\Delta$ V (mV)")
xlim(40,100)
savefig("FigEI_pre10.pdf")
# Out:
# /export/home1/users/bssn/serna/environments/neuron/lib/python3.6/site-packages/ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in sqrt
# /export/home1/users/bssn/serna/environments/neuron/lib/python3.6/site-packages/ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in sqrt

# %%
vaF = {}
meF = {}

# %%
ePSD = 0.04*exp(randn(500)*0.4+0.0)
iPSD = 0.04*exp(randn(500)*0.4+0.0)

hist(ePSD*1e3,31)
hist(iPSD*500,31)
# Out:
# (array([15., 36., 56., 68., 59., 58., 58., 39., 29., 18., 11., 13., 10.,
#          8.,  5.,  2.,  2.,  2.,  1.,  4.,  2.,  0.,  1.,  0.,  1.,  0.,
#          0.,  0.,  0.,  0.,  2.]),
#  array([ 7.36687303,  9.7104278 , 12.05398257, 14.39753733, 16.7410921 ,
#         19.08464686, 21.42820163, 23.77175639, 26.11531116, 28.45886592,
#         30.80242069, 33.14597546, 35.48953022, 37.83308499, 40.17663975,
#         42.52019452, 44.86374928, 47.20730405, 49.55085881, 51.89441358,
#         54.23796835, 56.58152311, 58.92507788, 61.26863264, 63.61218741,
#         65.95574217, 68.29929694, 70.6428517 , 72.98640647, 75.32996123,
#         77.673516  , 80.01707077]),
#  <a list of 31 Patch objects>)

# %%
dend.Ra = 250
neck.Ra = 250
model.E_PAS = -65
model.soma.e_pas = model.E_PAS
for dendp in model.dend:
    dendp.e_pas = model.E_PAS
for sp in model.spne:
    sp.e_pas = model.E_PAS

nrec = [5,10,20,40,80,160]
Ranecks = 250*exp(randn(500)*0.70+0.0)
ePSD = 0.04*exp(randn(500)*0.40+0.0)
iPSD = 0.04*exp(randn(500)*0.40+0.0)
nampas = ePSD*1e3
nnmdas = ePSD*10
ngabas = iPSD*.5e3

tdels = [-30,-20,-15,-10,-7.5,-5,-3.5,-2,-1,-0.5,0,0.5,1.0,2.0,2.75,3.5,5.0,10.0,20.,30.]


ngaba = 20
nampa = 40
ton = 50
tG = ton-10
t_stop = 200
toffset = 50
t_stop = 250
#nampa = 20
mes = zeros((len(tdels),6))
mes0 = zeros((len(tdels),6))
me2 = zeros((len(tdels),8))

for i,tG in enumerate(tdels):
    #lb.add_somaStim(model,p=0.5,onset=ton,dur=2, amp =0.0)
    nfir = 100
    mest = zeros((len(Ranecks),6))
    mest0 = zeros((len(Ranecks),6))
    vavg = zeros((int(t_stop/lb.h.dt+1),9))
    for j,Ra in enumerate(Ranecks):
        
        
        
        NC.weight[0] = nampas[j] *11/1e6
        NCN.weight[0] = gmaxN*0*nnmdas[j]
        NCG.weight[0] = ngabas[j]*30/1e6 
        neck.Ra = Ra
        #neck.Ra = 250
        #neck.L = Ra/250 
        neck.L = 1.0
        Rneckt = Rneck*Ra/250

        
        if tG>=0:
            NC.delay = toffset+ton-50
            NCN.delay = toffset+ton-50
            NCG.delay = toffset+tG#-50
        else:
            NC.delay = toffset+ton-tG-50
            NCN.delay = toffset+ton-tG-50
            NCG.delay = 0#-50
        NC.delay = toffset+ton-50
        NCN.delay = toffset+ton-50

        NCG.delay = t_stop
        
        lb.h.finitialize(model.E_PAS)

        lb.neuron.run(t_stop)

        current = abs(array(vDendRec[-2])-array(vDendRec[0]))/Rdend

        mest0[j,:] = [Rneckt,max(vspneRec[0])-model.E_PAS,max(vDendRec[1])-model.E_PAS,max(vrec)-model.E_PAS,max(current),tG]

        
        NCG.delay = toffset+tG#-50
        
        lb.h.finitialize(model.E_PAS)

        lb.neuron.run(t_stop)

        current = (array(vDendRec[-2])-array(vDendRec[0]))/Rdend

        vavg[:,0] += array(vspneRec[0]) 
        vavg[:,1] += array(vspneRec[0])**2
        vavg[:,2] += array(vDendRec[0]) 
        vavg[:,3] += array(vDendRec[0])**2
        vavg[:,4] += array(vrec) 
        vavg[:,5] += array(vrec)**2
        vavg[:,6] += current 
        vavg[:,7] += current**2
        vavg[:,-1] += 1
        current = abs(current)
        mest[j,:] = [Rneckt,max(vspneRec[0])-model.E_PAS,max(vDendRec[1])-model.E_PAS,max(vrec)-model.E_PAS,max(current),tG]
    mes[i,:] = mest.mean(axis=0)
    mes0[i,:] = mest0.mean(axis=0)
    mest0 = mest[:,1:-1]/mest0[:,1:-1]
    me2[i,:] = concatenate((mest0.mean(axis=0),mest0.std(axis=0)))

    vavg[:,:-1] = vavg[:,:-1]/vavg[0,-1]
    vavg[:,1] = sqrt(vavg[:,1]-vavg[:,0]**2)#/sqrt(vavg[0,-1])
    vavg[:,3] = sqrt(vavg[:,3]-vavg[:,2]**2)#/sqrt(vavg[0,-1])
    vavg[:,5] = sqrt(vavg[:,5]-vavg[:,4]**2)#/sqrt(vavg[0,-1])

    fig = figure(figsize=(13,6))
    #ax = fig.add_subplot(121)

    ImaxnA = 1# (NC.weight[0]/area/model.CM*1e6)

    #sel = mes[:,0].argsort()
    #plot(mes[sel,-2]/1e-12/ImaxnA,mes[sel,1]-vavg[0,0],label="Spine head")
    #plot(mes[sel,-2]/1e-12/ImaxnA,mes[sel,2]-vavg[0,0],label="Dendritic shaft")
    #plot(mes[sel,-2]/1e-12/ImaxnA,mes[sel,3]-vavg[0,0],label="Soma")

    #xlabel("I(pA)/I_max")
    #xlabel("I(pA)")

    #ylabel("V (mV)")

    #ax = fig.add_subplot(122)
    vavt = vavg[:,:2]*1.0
    vavt[:,0] = vavg[:,0]-vavg[0,0] 
    plot(trec,vavt[:,0]-vavt[0,0],label="Spine head")
    fill_between(trec,vavt[:,0]+vavt[:,1],vavt[:,0]-vavt[:,1])
    xlabel("t (ms)")
    ylabel("V (mV)")
    xlim(toffset+40,toffset+100)
    savefig("FigEI_t"+str(int(tG*10)).zfill(3)+".png")
    vaF[tG] = vavg*1.0
    meF[tG] = mest*1.0
# Out:
# /export/home1/users/bssn/serna/environments/neuron/lib/python3.6/site-packages/ipykernel_launcher.py:100: RuntimeWarning: invalid value encountered in sqrt
# /export/home1/users/bssn/serna/environments/neuron/lib/python3.6/site-packages/ipykernel_launcher.py:101: RuntimeWarning: invalid value encountered in sqrt
# /export/home1/users/bssn/serna/environments/neuron/lib/python3.6/site-packages/ipykernel_launcher.py:102: RuntimeWarning: invalid value encountered in sqrt

# %%
medata = 1.0*mes
medata0 = 1.0*mes0
medata2 = 1.0*me2

# %%
figure()
hist(mest[:,0]/1e6,31)
xlabel("$R_{neck}$")
# Out:
# Text(0.5, 0, '$R_{neck}$')

# %%
figure(figsize=(8,5))
#me2 = 1.0*medata2
sel = mes[:,0].argsort()
plot(tdels,me2[:,0],'.-',label=int(mes[0,-1]))
fill_between(tdels,me2[:,0]+me2[:,0+4],me2[:,0]-me2[:,0+4])

xlabel("t(ms)")
ylabel("$\Delta V/\Delta V_{no GABA}$")
#legend(title="$n_{GABAR}$")
# Out:
# Text(0, 0.5, '$\\Delta V/\\Delta V_{no GABA}$')

# %%
data = zeros((len(meF.keys()),6))
figure(figsize=(8,5))
for i,key in enumerate(meF.keys()):
    vavg = 1.0*vaF[key]
    vavt = vavg[:,:2]*1.0
    vavt[:,0] = vavg[:,0]-vavg[0,0] 
    data[i,:3] = [max(vavt[:,0]),max(vavt[:,0]+vavt[:,1]),max(vavt[:,0]-vavt[:,1])]
    vavt = abs(vavg[:,-3:-1])
    data[i,3:] = [max(vavt[:,0]),max(vavt[:,0]+vavt[:,1]),max(vavt[:,0]-vavt[:,1])]
    mes = 1.0*meF[key]
    sel = mes[:,0].argsort()
    l = len(mes[:,0])
    me,q1,q2 = (mean(log(mes[:,1]-vavg[0,0])),log(mes[sel[l*5//100],1]-vavg[0,0]),log(mes[sel[l*95//100],1]-vavg[0,0]))
    data[i,:3] = [exp(me),exp(q1),exp(q2)]
    me,q1,q2 = (mean(log(mes[:,-2]*1e12)),log(mes[sel[l*5//100],-2]*1e12),log(mes[sel[l*95//100],-2]*1e12))
    data[i,3:] = [exp(me),exp(q1),exp(q2)]
    
    plot(mes[sel,-2]/1e-12,mes[sel,1]-vavg[0,0],label=int(mes[0,-1]))
    
plot(data[:,3],data[:,0],'k--')
#plot(data[:,5],data[:,2],'k--')
#plot(data[:,4],data[:,1],'k--')

xlim(0,1600)
fill_between(data[:,4],interp(data[:,4],data[:,5],data[:,2]),data[:,1],color='gray',alpha=0.7)
xlabel("I(pA)")
ylabel("$\Delta V$")
legend(title="$n_{AMPAR}$")

# %%
fig = figure(figsize=(14,5))

ax = fig.add_subplot(121)
for i,key in enumerate(meF.keys()):
    mes = 1.0*meF[key]
    sel = mes[:,0].argsort()
    plot(mes[sel,-2]/1e-12,mes[sel,1]-vavg[0,0],label=int(mes[0,-1]))
    
plot(data[:,3],data[:,0],'k--')
plot(data[:,5],data[:,2],'k--')
plot(data[:,4],data[:,1],'k--')

xlim(0,1600)
fill_between(data[:,4],interp(data[:,4],data[:,5],data[:,2]),data[:,1],color='gray',alpha=0.7)
xlabel("I(pA)")
ylabel("$\Delta V$")
legend(title="# AMPAR")


ax = fig.add_subplot(122)
vavg = vaF[40.0]
vavt = vavg[:,:2]*1.0
vavt[:,0] = vavg[:,0]-vavg[0,0] 
plot(trec,vavt[:,0]-vavt[0,0],label="40 AMPAR")
fill_between(trec,vavt[:,0]+vavt[:,1],vavt[:,0]-vavt[:,1])
xlabel("t (ms)")
ylabel("V (mV)")
xlim(40,100)

vavg = vaF[10.0]
vavt = vavg[:,:2]*1.0
vavt[:,0] = vavg[:,0]-vavg[0,0] 
plot(trec,vavt[:,0]-vavt[0,0],label="10 AMPAR")
fill_between(trec,vavt[:,0]+vavt[:,1],vavt[:,0]-vavt[:,1])
legend()


figure()
hist(mes[:,0]/1e6,31)
xlabel("$R_{neck}$")
# Out:
# Text(0.5, 0, '$R_{neck}$')

# %%
area = model.spne[0].L*(model.spne[0].diam/2)**2*2*pi/2
print("Synaptic conductance: g_s= %.3f nS " % (NC.weight[0]*1e3)) # nS
print("Membrane surface of spyne: A= %.4f  um2 " % area)
print("Max. synaptic current: g_s/(c_m A) = %.2f (pA)" % (NC.weight[0]/area/model.CM*1e6))
# Out:
# Synaptic conductance: g_s= 0.300 nS
# Membrane surface of spyne: A= 0.7854  um2
# Max. synaptic current: g_s/(c_m A) = 381.97 (pA)

# %%
model.neck[0].L
# Out:
# 1.4
